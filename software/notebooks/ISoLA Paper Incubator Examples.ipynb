# %%
import os
os.chdir("../")

# %%
!pwd
# Out:
# /workspaces/example_digital-twin_incubator_twright/software

# %% [markdown]
# # Incubator Case Study

# %%
from verified_twin.lbuc import *

from sage.symbolic.function_factory import function_factory

from verified_twin.base import *
from verified_twin.parametric_models import ParametricModel
from verified_twin.incubator_models import (SwitchingFourParameterModel, 
    SwitchingFourParameterModelCAGB)
from verified_twin.controllers import BasicController, TrivialController, SignalSwitchedController
from verified_twin.simulators import VerifiedContinuousSimulator, DiscreteSimulator, HybridSimulator

# %%
var("t, T_S, T_H, T_A, T_F, C_S, C_H, C_A, C_F, I, T_R, G_S, G_H, G_B, G_F, V")
# Out:
# (t, T_S, T_H, T_A, T_F, C_S, C_H, C_A, C_F, I, T_R, G_S, G_H, G_B, G_F, V)

# %%
incubator = SwitchingFourParameterModel([RIF("0"), RIF('[25.0, 25.1]'), RIF('[20.5935,21.5935]')])

# %%
incubator = SwitchingFourParameterModelCAGB([RIF("0"), RIF('[25.0, 25.1]'), RIF('[20.5935,21.5935]'), RIF("[68.20829072,68.70829072]"), RIF("[0.73572788,0.78572788]")])

# %% [markdown]
# ## Parametic model with an abstracted controller

# %% [markdown]
# ### Most basic

# %%
rs = VerifiedContinuousSimulator({'heater_on': False}, incubator).run(RIF(0), RIF(1000.5), RIF("Inf")); rs

# %%
rs.values

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 8000 graphics primitives

# %%
_.save("../plots/uncertain-model-stabalising.pdf")

# %%
g = Atomic(T_A > 22.6).signal(rs, symbolic_composition=True).plot()

# %%
g.set_aspect_ratio(60)
g
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
g.save("../plots/atomic-proposition-three-valued-signal.pdf")

# %%
G(RIF(0,1000), ~Atomic(T_A > RIF(22.6)) | Atomic(T_H > RIF(23)) ).signal(rs)
# Out:
# In G.signal
# mask for G = None
# Signal([0.0000000000000000 .. 1000.5000000000000], [([0.0000000000000000 .. 0.50000000000000000], True)], mask=None)

# %%
from verified_twin.traces import RealTimeTrace, HybridTrace, ContinuousTrace, VerifiedContinuousTrace

# %% [markdown]
# ### Example with a fixed sequence of control decisions

# %%
upm = HybridSimulator(incubator, TrivialController({'heater_on': False}))

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 8000 graphics primitives

# %% [markdown]
# ### Generalisation to a signal representing the control decisions

# %%
heater_sig = Signal(RIF(0,600),
                    [
                        (RIF("[0, 21.98]"), True),
                        (RIF("[21.99, 52.98]"), False),
                        (RIF("[52.99, 74.98]"), True),
                        (RIF("[74.99, 105.98]"), False),
                        (RIF("[105.99, 127.98]"), True),
                        (RIF("[127.99, 600]"), False)
                    ])

# %%
heater_sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# We want to parameterize the control decisions based on a signal so we can replay any set sequence of control decisions within the model

# %%
fspm = HybridSimulator(intervalfourpm, SignalSwitchedController({'heater_on': False}, {'heater_on': heater_sig}))

# %%
rs = fspm.run(time_limit=RIF(600))
# Out:
# x = [0, 25, 3.?e1]
# state = {'heater_on': True}
# running for [21.980000000000000 .. 21.980000000000001] ...
# x = [21.980000000?, 36.?, 3.?e1]
# state = {'heater_on': False}
# running for [30.999999999111565 .. 31.000000000892463] ...
# x = [52.98000000?, 35.?, 3.?e1]
# state = {'heater_on': True}
# running for [21.999999997583152 .. 22.000000003307094] ...
# x = [74.98000000?, 45.?, 29.?]
# state = {'heater_on': False}
# running for [30.999999993173844 .. 31.000000006831542] ...
# x = [105.9800000?, 44.?, 31.?]
# state = {'heater_on': True}
# running for [21.999999991601470 .. 22.000000015246301] ...
# x = [127.9800000?, 54.?, 34.?]
# state = {'heater_on': False}
# running for [472.01999997372257 .. 472.02000001852998] ...

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 4772 graphics primitives

# %%
_.save("plots/controlled-uncertain-model-stabalising.pdf")

# %% [markdown]
# ### Periodic Open Loop Controller

# %%
from verified_twin.controllers import PeriodicOpenLoopController

# %%
fspm = HybridSimulator(
    incubator,
    PeriodicOpenLoopController(3.0, 10, 1),
    controller_input_map=(lambda x: x[0]),
    controller_output_map=(lambda xin, x: xin),
)

# %%
rs = fspm.run(time_limit=RIF(3000))

# %%
rs.values
# Out:
# [{'heater_on': False, 'current_state': <OpenLoopState.INITIALIZED: 1>},
#  {'heater_on': False, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fec05dadb80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fec05dadca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fec05daddc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fec05dadee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513ba040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513ba160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513ba280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513ba3a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513ba4c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513ba5e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513ba700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513ba820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513ba940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513baa60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513bab80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513baca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee513badc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee513baee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d4040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d4160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d4280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d43a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d44c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d45e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d4700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d4820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d4940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d4a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d4b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d4ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293d4dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293d4ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ef040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ef160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ef280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ef3a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ef4c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ef5e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ef700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ef820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ef940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293efa60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293efb80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293efca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293efdc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293efee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c8040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c8160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c8280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c83a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c84c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c85e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c8700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c8820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c8940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c8a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c8b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c8ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293c8dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293c8ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ea040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ea160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ea280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ea3a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ea4c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ea5e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ea700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293ea820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293ea940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293eaa60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293eab80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293eaca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee293eadc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee293eaee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126a040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126a160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126a280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126a3a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126a4c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126a5e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126a700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126a820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126a940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126aa60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126ab80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126aca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5126adc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5126aee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127a040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127a160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127a280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127a3a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127a4c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127a5e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127a700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127a820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127a940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127aa60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127ab80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127aca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5127adc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5127aee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee51288040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee51288160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee51288280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee512883a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee512884c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee512885e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee51288700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee51288820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee51288940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee51288a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee51288b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee51288ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee51288dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee51288ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab53a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab54c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab55e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab5ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab93a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab94c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab95e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2bab9ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba893a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba894c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba895e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba89ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba923a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba924c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba925e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee2ba92ee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734d040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734d160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734d280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734d3a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734d4c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734d5e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734d700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734d820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734d940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734da60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734db80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734dca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee5734ddc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee5734dee0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee57323040>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee57323160>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee57323280>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee573233a0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee573234c0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee573235e0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee57323700>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee57323820>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee57323940>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee57323a60>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee57323b80>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee57323ca0>,
#  {'heater_on': True, 'current_state': <OpenLoopState.HEATING: 2>},
#  <flowstar.reachability.Reach object at 0x7fee57323dc0>,
#  {'heater_on': False, 'current_state': <OpenLoopState.COOLING: 3>},
#  <flowstar.reachability.Reach object at 0x7fee57323ee0>]

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 23200 graphics primitives

# %%
_.save("../plots/long-term-heating.pdf")

# %%
g = Atomic(T_A > 22.6).signal(rs, symbolic_composition=True).plot()

# %%
g.set_aspect_ratio(180)
g
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
_.save("../plots/long-term-heating-signal.pdf")

# %%
sig = F(RIF(0, 2000), G(RIF(0, 100), Atomic(T_A > 33) & Atomic(T_A < 36))).signal(rs)
sig
# Out:
# mask for F = None
# In G.signal
# mask for G = None
# and mask = None
# and sig = None
# and mask = None
# and sig = None
# Signal([0.0000000000000000 .. 3000.0000000000000], [([0.0000000000000000 .. 1202.4995352182282], True)], mask=None)

# %% [markdown]
# ### Using a numpy array of control point samples for callibrator integration

# %%
from verified_twin.controllers import SignalArraySwitchedController

# %%
import numpy as np

timepoints = np.array([0.0, 22.0, 53.0, 75.0, 106.0, 128.0])
state_arrays = {
    'heater_on': np.array([True, False, True, False, True, False]),
}

# %%
controller = SignalArraySwitchedController(
    {'heater_on': False},
    timepoints,
    state_arrays,
)

# %%
controller.current_signal_state(21.0, None, timepoints, state_arrays['heater_on'])
# Out:
# True

# %%
controller.next_state_update({'heater_on': False}, 0.0)
# Out:
# ('heater_on', (0.0, True))

# %%
[
    (k, controller.next_signal_change(0.0, False, timepoints, sig_arr))
    for k, sig_arr
    in controller.input_signals_arrays.items()
]
# Out:
# [('heater_on', (0.0, True))]

# %%
controller.next_signal_change(1.0, False, timepoints, state_arrays['heater_on'])
# Out:
# (53.0, True)

# %%
fspm = HybridSimulator(
    intervalfourpm, controller,
    controller_input_map=(lambda x: x[0]),
    controller_output_map=(lambda xin, x: xin),
)

# %%
rs = fspm.run(time_limit=RIF("600")); rs
# Out:
# x = [0, 25, 3.?e1]
# state = {'heater_on': True}
# running for [22.000000000000000 .. 22.000000000000000] ...
# x = [22.000000000?, 36.?, 3.?e1]
# state = {'heater_on': False}
# running for [30.999999999111523 .. 31.000000000892506] ...
# x = [53.00000000?, 35.?, 3.?e1]
# state = {'heater_on': True}
# running for [21.999999997583117 .. 22.000000003307165] ...
# x = [75.00000000?, 45.?, 29.?]
# state = {'heater_on': False}
# running for [30.999999993174029 .. 31.000000006831343] ...
# x = [106.0000000?, 44.?, 31.?]
# state = {'heater_on': True}
# running for [21.999999991601654 .. 22.000000015245931] ...
# x = [128.0000000?, 54.?, 34.?]
# state = {'heater_on': False}
# running for [471.99999997372304 .. 472.00000001852971] ...

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 4772 graphics primitives

# %% [markdown]
# ### Now with an actual controller

# %% [markdown]
# Now to add in the actual controller in order to trigger the control steps based on the actual system state rather than just looking playing out a fixed sequence of steps...

# %% [markdown]
# The controller takes much smaller steps than expected. We should not simply be calculating the next heater turn on time but instead, sampling every $n$ seconds, detecting the conditions to activate the heater, and in this case scheduling the turn on time for a suitable gap in the future. Heater can still turn on again if we do go below the lower bound.
#
# States:
#  - *CoolingDown:* the heater has already fired so we wait until we are below the lower bound and turn on if we have gone too low (go to heating)
#  - *Heating:* we keep the heater on until next time and turn off afterwards (go to waiting)
#  - *Waiting:* We wait until heating gap has elapsed until it can be turned on again. If in_temperature exceeds desired *after next time*, we immediately start heating again. If not, we start waiting again.

# %%
from enum import Enum, auto

class IncubatorState(Enum):
    COOLING_DOWN = 'CoolingDown'
    HEATING = 'Heating'
    WAITING = 'Waiting'

# %%
class PeriodicBurstIncubatorController(BasicController):
    def __init__(self, initial_state,
                 temperature_desired=RIF("45.0"),
                 lower_bound=RIF("10.0"), heating_time=RIF("0.2"),
                 heating_gap=RIF("0.3")):
        self.temperature_desired = RIF(temperature_desired)
        self.lower_bound = RIF(lower_bound)
        self.heating_time = RIF(heating_time)
        self.heating_gap = RIF(heating_gap)
        self.in_temperature = RIF("20")
        super().__init__(initial_state)

    def control_step(self, xs, state):
        print(f"controller input = {xs}")
        t, x = xs
        new_state = dict(**state)
        
        if state['current_state'] == IncubatorState.COOLING_DOWN:
            new_state['heater_on'] = False
            # if self.in_temperature.upper() <= (self.temperature_desired - self.lower_bound).lower():
            if x <= (self.temperature_desired - self.lower_bound):
                new_state['current_state'] = IncubatorState.HEATING
                new_state['next_time'] = t + RIF(self.heating_time)
        elif state['current_state'] == IncubatorState.HEATING:
            new_state['heater_on'] = True
            if new_state['next_time'] <= t:
                new_state['current_state'] = IncubatorState.WAITING
                new_state['next_time'] = t + RIF(self.heating_gap)
        elif state['current_state'] == IncubatorState.WAITING:
            new_state['heater_on'] = False
            if new_state['next_time'] <= t:
                new_state['current_state'] = IncubatorState.HEATING
                new_state['next_time'] = t + self.heating_time
            else:
                new_state['current_state'] = IncubatorState.COOLING_DOWN
                new_state['next_time'] = None
        else:
            raise Exception("Invalid controller state!")
            
        return (RIF('Inf'), x, new_state)

# %% [markdown]
# With control based on the value of the air temperature

# %%
fspm = HybridSimulator(
    intervalfourpm,
    PeriodicBurstIncubatorController(
        {'current_state': IncubatorState.COOLING_DOWN, 'next_time': RIF(0), 'heater_on': False},
        heating_time=22, heating_gap=31, temperature_desired=35, lower_bound=10,
    ),
    controller_input_map=(lambda x: (x[0], x[2])),
    controller_output_map=(lambda xin, x: xin),
)

# %%
rs = fspm.run(RIF(3000), RIF(3))
# Out:
# x = [0, 25, 3.?e1]
# controller input = (0, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [3.00000000000?, 25.0?, 3.?e1]
# controller input = (3.00000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [6.0000000000?, 26.5?, 3.?e1]
# controller input = (6.0000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [9.0000000000?, 28.0?, 3.?e1]
# controller input = (9.0000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [12.000000000?, 30.?, 3.?e1]
# controller input = (12.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [15.000000000?, 31.?, 3.?e1]
# controller input = (15.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [18.000000000?, 33.?, 3.?e1]
# controller input = (18.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [21.000000000?, 34.?, 3.?e1]
# controller input = (21.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [24.000000000?, 36.?, 3.?e1]
# controller input = (24.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 55.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [27.000000000?, 37.?, 3.?e1]
# controller input = (27.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [30.000000000?, 37.?, 3.?e1]
# controller input = (30.000000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [33.00000000?, 37.?, 3.?e1]
# controller input = (33.00000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [36.00000000?, 37.?, 3.?e1]
# controller input = (36.00000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [39.00000000?, 37.?, 3.?e1]
# controller input = (39.00000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [42.00000000?, 36.?, 26.?]
# controller input = (42.00000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [45.00000000?, 36.?, 26.?]
# controller input = (45.00000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [48.00000000?, 36.?, 3.?e1]
# controller input = (48.00000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [51.00000000?, 36.?, 3.?e1]
# controller input = (51.00000000?, 3.?e1)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [54.00000000?, 36.?, 27.?]
# controller input = (54.00000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [57.00000000?, 36.?, 27.?]
# controller input = (57.00000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [60.00000000?, 36.?, 27.?]
# controller input = (60.00000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [63.00000000?, 36.?, 27.?]
# controller input = (63.00000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [66.00000000?, 36.?, 27.?]
# controller input = (66.00000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [69.00000000?, 36.?, 27.?]
# controller input = (69.00000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [72.00000000?, 35.?, 28.?]
# controller input = (72.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [75.00000000?, 35.?, 28.?]
# controller input = (75.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [78.00000000?, 35.?, 28.?]
# controller input = (78.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [81.00000000?, 35.?, 28.?]
# controller input = (81.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [84.00000000?, 35.?, 28.?]
# controller input = (84.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [87.00000000?, 35.?, 28.?]
# controller input = (87.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [90.00000000?, 35.?, 28.?]
# controller input = (90.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [93.00000000?, 35.?, 28.?]
# controller input = (93.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [96.00000000?, 35.?, 28.?]
# controller input = (96.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [99.00000000?, 35.?, 28.?]
# controller input = (99.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [102.00000000?, 35.?, 28.?]
# controller input = (102.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [105.00000000?, 35.?, 28.?]
# controller input = (105.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [108.00000000?, 35.?, 28.?]
# controller input = (108.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [111.00000000?, 34.?, 28.?]
# controller input = (111.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [114.00000000?, 34.?, 28.?]
# controller input = (114.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [117.00000000?, 34.?, 28.?]
# controller input = (117.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [120.00000000?, 34.?, 28.?]
# controller input = (120.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [123.00000000?, 34.?, 28.?]
# controller input = (123.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [126.00000000?, 34.?, 28.?]
# controller input = (126.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [129.00000000?, 34.?, 28.?]
# controller input = (129.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [132.00000000?, 34.?, 28.?]
# controller input = (132.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [135.00000000?, 34.?, 28.?]
# controller input = (135.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [138.00000000?, 34.?, 28.?]
# controller input = (138.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [141.00000000?, 34.?, 28.?]
# controller input = (141.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [144.00000000?, 34.?, 28.?]
# controller input = (144.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [147.00000000?, 34.?, 28.?]
# controller input = (147.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [150.00000000?, 34.?, 28.?]
# controller input = (150.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [153.00000000?, 34.?, 28.?]
# controller input = (153.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [156.00000000?, 34.?, 28.?]
# controller input = (156.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [159.00000000?, 34.?, 28.?]
# controller input = (159.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [162.00000000?, 33.?, 28.?]
# controller input = (162.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [165.00000000?, 33.?, 28.?]
# controller input = (165.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [168.00000000?, 33.?, 28.?]
# controller input = (168.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [171.00000000?, 33.?, 28.?]
# controller input = (171.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [174.00000000?, 33.?, 28.?]
# controller input = (174.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [177.00000000?, 33.?, 28.?]
# controller input = (177.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [180.00000000?, 33.?, 28.?]
# controller input = (180.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [183.00000000?, 33.?, 28.?]
# controller input = (183.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [186.00000000?, 33.?, 28.?]
# controller input = (186.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [189.00000000?, 33.?, 28.?]
# controller input = (189.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [192.00000000?, 33.?, 28.?]
# controller input = (192.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [195.00000000?, 33.?, 28.?]
# controller input = (195.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [198.00000000?, 33.?, 28.?]
# controller input = (198.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [201.00000000?, 33.?, 28.?]
# controller input = (201.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [204.00000000?, 33.?, 28.?]
# controller input = (204.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [207.00000000?, 33.?, 28.?]
# controller input = (207.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [210.00000000?, 33.?, 28.?]
# controller input = (210.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [213.00000000?, 33.?, 28.?]
# controller input = (213.00000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [216.0000000?, 33.?, 28.?]
# controller input = (216.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [219.0000000?, 32.?, 28.?]
# controller input = (219.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [222.0000000?, 32.?, 28.?]
# controller input = (222.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [225.0000000?, 32.?, 28.?]
# controller input = (225.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [228.0000000?, 32.?, 28.?]
# controller input = (228.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [231.0000000?, 32.?, 28.?]
# controller input = (231.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [234.0000000?, 32.?, 28.?]
# controller input = (234.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [237.0000000?, 32.?, 28.?]
# controller input = (237.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [240.0000000?, 32.?, 28.?]
# controller input = (240.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [243.0000000?, 32.?, 28.?]
# controller input = (243.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [246.0000000?, 32.?, 28.?]
# controller input = (246.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [249.0000000?, 32.?, 28.?]
# controller input = (249.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [252.0000000?, 32.?, 28.?]
# controller input = (252.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [255.0000000?, 32.?, 28.?]
# controller input = (255.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [258.0000000?, 32.?, 28.?]
# controller input = (258.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [261.0000000?, 32.?, 28.?]
# controller input = (261.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [264.0000000?, 32.?, 28.?]
# controller input = (264.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [267.0000000?, 32.?, 28.?]
# controller input = (267.0000000?, 28.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [270.0000000?, 32.?, 27.?]
# controller input = (270.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [273.0000000?, 32.?, 27.?]
# controller input = (273.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [276.0000000?, 32.?, 27.?]
# controller input = (276.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [279.0000000?, 32.?, 27.?]
# controller input = (279.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [282.0000000?, 31.?, 27.?]
# controller input = (282.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [285.0000000?, 31.?, 27.?]
# controller input = (285.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [288.0000000?, 31.?, 27.?]
# controller input = (288.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [291.0000000?, 31.?, 27.?]
# controller input = (291.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [294.0000000?, 31.?, 27.?]
# controller input = (294.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [297.0000000?, 31.?, 27.?]
# controller input = (297.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [300.0000000?, 31.?, 27.?]
# controller input = (300.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [303.0000000?, 31.?, 27.?]
# controller input = (303.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [306.0000000?, 31.?, 27.?]
# controller input = (306.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [309.0000000?, 31.?, 27.?]
# controller input = (309.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [312.0000000?, 31.?, 27.?]
# controller input = (312.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [315.0000000?, 31.?, 27.?]
# controller input = (315.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [318.0000000?, 31.?, 27.?]
# controller input = (318.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [321.0000000?, 31.?, 27.?]
# controller input = (321.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [324.0000000?, 31.?, 27.?]
# controller input = (324.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [327.0000000?, 31.?, 27.?]
# controller input = (327.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [330.0000000?, 31.?, 27.?]
# controller input = (330.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [333.0000000?, 31.?, 27.?]
# controller input = (333.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [336.0000000?, 31.?, 27.?]
# controller input = (336.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [339.0000000?, 31.?, 27.?]
# controller input = (339.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [342.0000000?, 31.?, 27.?]
# controller input = (342.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [345.0000000?, 31.?, 27.?]
# controller input = (345.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [348.0000000?, 31.?, 27.?]
# controller input = (348.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [351.0000000?, 31.?, 27.?]
# controller input = (351.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [354.0000000?, 30.?, 27.?]
# controller input = (354.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [357.0000000?, 30.?, 27.?]
# controller input = (357.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [360.0000000?, 30.?, 27.?]
# controller input = (360.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [363.0000000?, 30.?, 27.?]
# controller input = (363.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [366.0000000?, 30.?, 27.?]
# controller input = (366.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [369.0000000?, 30.?, 27.?]
# controller input = (369.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [372.0000000?, 30.?, 27.?]
# controller input = (372.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [375.0000000?, 30.?, 27.?]
# controller input = (375.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [378.0000000?, 30.?, 27.?]
# controller input = (378.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [381.0000000?, 30.?, 27.?]
# controller input = (381.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [384.0000000?, 30.?, 27.?]
# controller input = (384.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [387.0000000?, 30.?, 27.?]
# controller input = (387.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [390.0000000?, 30.?, 27.?]
# controller input = (390.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [393.0000000?, 30.?, 27.?]
# controller input = (393.0000000?, 27.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [396.0000000?, 30.?, 26.?]
# controller input = (396.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [399.0000000?, 30.?, 26.?]
# controller input = (399.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [402.0000000?, 30.?, 26.?]
# controller input = (402.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [405.0000000?, 30.?, 26.?]
# controller input = (405.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [408.0000000?, 30.?, 26.?]
# controller input = (408.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [411.0000000?, 30.?, 26.?]
# controller input = (411.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [414.0000000?, 30.?, 26.?]
# controller input = (414.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [417.0000000?, 30.?, 26.?]
# controller input = (417.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [420.0000000?, 30.?, 26.?]
# controller input = (420.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [423.0000000?, 30.?, 25.9?]
# controller input = (423.0000000?, 25.9?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [426.0000000?, 30.?, 26.?]
# controller input = (426.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [429.0000000?, 30.?, 26.?]
# controller input = (429.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [432.0000000?, 30.?, 26.?]
# controller input = (432.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [435.0000000?, 29.?, 26.?]
# controller input = (435.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [438.0000000?, 29.?, 25.8?]
# controller input = (438.0000000?, 25.8?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [441.0000000?, 29.?, 26.?]
# controller input = (441.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [444.0000000?, 29.?, 26.?]
# controller input = (444.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [447.0000000?, 29.?, 26.?]
# controller input = (447.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [450.0000000?, 29.?, 26.?]
# controller input = (450.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [453.0000000?, 29.?, 25.7?]
# controller input = (453.0000000?, 25.7?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [456.0000000?, 29.?, 26.?]
# controller input = (456.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [459.0000000?, 29.?, 26.?]
# controller input = (459.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [462.0000000?, 29.?, 26.?]
# controller input = (462.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [465.0000000?, 29.?, 26.?]
# controller input = (465.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [468.0000000?, 29.?, 25.6?]
# controller input = (468.0000000?, 25.6?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [471.0000000?, 29.?, 26.?]
# controller input = (471.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [474.0000000?, 29.?, 26.?]
# controller input = (474.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [477.0000000?, 29.?, 26.?]
# controller input = (477.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [480.0000000?, 29.?, 26.?]
# controller input = (480.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [483.0000000?, 29.?, 25.5?]
# controller input = (483.0000000?, 25.5?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [486.0000000?, 29.?, 26.?]
# controller input = (486.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [489.0000000?, 29.?, 26.?]
# controller input = (489.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [492.0000000?, 29.?, 26.?]
# controller input = (492.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [495.0000000?, 29.?, 26.?]
# controller input = (495.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [498.0000000?, 29.?, 25.4?]
# controller input = (498.0000000?, 25.4?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [501.0000000?, 29.?, 25.4?]
# controller input = (501.0000000?, 25.4?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [504.0000000?, 29.?, 26.?]
# controller input = (504.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [507.0000000?, 29.?, 26.?]
# controller input = (507.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [510.0000000?, 29.?, 26.?]
# controller input = (510.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [513.0000000?, 29.?, 25.3?]
# controller input = (513.0000000?, 25.3?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [516.0000000?, 29.?, 25.3?]
# controller input = (516.0000000?, 25.3?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [519.0000000?, 29.?, 26.?]
# controller input = (519.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [522.0000000?, 29.?, 26.?]
# controller input = (522.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [525.0000000?, 29.?, 26.?]
# controller input = (525.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [528.0000000?, 28.?, 26.?]
# controller input = (528.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [531.0000000?, 28.?, 25.2?]
# controller input = (531.0000000?, 25.2?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [534.0000000?, 28.?, 25.2?]
# controller input = (534.0000000?, 25.2?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [537.0000000?, 28.?, 26.?]
# controller input = (537.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [540.0000000?, 28.?, 26.?]
# controller input = (540.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [543.0000000?, 28.?, 26.?]
# controller input = (543.0000000?, 26.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [546.0000000?, 28.?, 25.1?]
# controller input = (546.0000000?, 25.1?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [549.0000000?, 28.?, 25.1?]
# controller input = (549.0000000?, 25.1?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [552.0000000?, 28.?, 25.1?]
# controller input = (552.0000000?, 25.1?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [555.0000000?, 28.?, 25.?]
# controller input = (555.0000000?, 25.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [558.0000000?, 28.?, 25.?]
# controller input = (558.0000000?, 25.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [561.0000000?, 28.?, 25.?]
# controller input = (561.0000000?, 25.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [564.0000000?, 28.?, 25.0?]
# controller input = (564.0000000?, 25.0?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [567.0000000?, 28.?, 25.0?]
# controller input = (567.0000000?, 25.0?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [570.0000000?, 28.?, 25.0?]
# controller input = (570.0000000?, 25.0?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [573.0000000?, 28.?, 25.?]
# controller input = (573.0000000?, 25.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [576.0000000?, 28.?, 25.?]
# controller input = (576.0000000?, 25.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [579.0000000?, 28.?, 25.?]
# controller input = (579.0000000?, 25.?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [582.0000000?, 28.?, 24.9?]
# controller input = (582.0000000?, 24.9?)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 604.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [585.0000000?, 28.?, 24.9?]
# controller input = (585.0000000?, 24.9?)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 604.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [588.0000000?, 29.?, 24.9?]
# controller input = (588.0000000?, 24.9?)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 604.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [591.0000000?, 31.?, 25.0?]
# controller input = (591.0000000?, 25.0?)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 604.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [594.0000000?, 32.?, 25.1?]
# controller input = (594.0000000?, 25.1?)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 604.0000000?, 'heater_on': True}
# ...
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2808.000000?, 34.94?, 29.08?]
# controller input = (2808.000000?, 29.08?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2811.000000?, 34.88?, 29.05?]
# controller input = (2811.000000?, 29.05?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2814.000000?, 34.82?, 29.02?]
# controller input = (2814.000000?, 29.02?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2817.000000?, 34.75?, 28.99?]
# controller input = (2817.000000?, 28.99?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2820.000000?, 34.69?, 28.96?]
# controller input = (2820.000000?, 28.96?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2823.000000?, 34.63?, 28.93?]
# controller input = (2823.000000?, 28.93?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2826.000000?, 34.57?, 28.90?]
# controller input = (2826.000000?, 28.90?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2829.000000?, 34.51?, 28.87?]
# controller input = (2829.000000?, 28.87?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2832.000000?, 34.45?, 28.84?]
# controller input = (2832.000000?, 28.84?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2835.000000?, 34.39?, 28.81?]
# controller input = (2835.000000?, 28.81?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2838.000000?, 34.33?, 28.78?]
# controller input = (2838.000000?, 28.78?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2841.000000?, 34.27?, 28.75?]
# controller input = (2841.000000?, 28.75?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2844.000000?, 34.21?, 28.72?]
# controller input = (2844.000000?, 28.72?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2847.000000?, 34.15?, 28.69?]
# controller input = (2847.000000?, 28.69?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2850.000000?, 34.09?, 28.66?]
# controller input = (2850.000000?, 28.66?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2853.000000?, 34.04?, 28.63?]
# controller input = (2853.000000?, 28.63?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2856.000000?, 33.98?, 28.59?]
# controller input = (2856.000000?, 28.59?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2859.000000?, 33.92?, 28.56?]
# controller input = (2859.000000?, 28.56?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2862.000000?, 33.86?, 28.53?]
# controller input = (2862.000000?, 28.53?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2865.000000?, 33.81?, 28.50?]
# controller input = (2865.000000?, 28.50?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2868.000000?, 33.75?, 28.47?]
# controller input = (2868.000000?, 28.47?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2871.000000?, 33.69?, 28.44?]
# controller input = (2871.000000?, 28.44?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2874.000000?, 33.64?, 28.41?]
# controller input = (2874.000000?, 28.41?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2877.000000?, 33.58?, 28.38?]
# controller input = (2877.000000?, 28.38?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2880.000000?, 33.52?, 28.34?]
# controller input = (2880.000000?, 28.34?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2883.000000?, 33.47?, 28.31?]
# controller input = (2883.000000?, 28.31?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2886.000000?, 33.41?, 28.28?]
# controller input = (2886.000000?, 28.28?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2889.000000?, 33.36?, 28.25?]
# controller input = (2889.000000?, 28.25?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2892.000000?, 33.30?, 28.22?]
# controller input = (2892.000000?, 28.22?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2895.000000?, 33.25?, 28.19?]
# controller input = (2895.000000?, 28.19?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2898.000000?, 33.20?, 28.16?]
# controller input = (2898.000000?, 28.16?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2901.000000?, 33.14?, 28.13?]
# controller input = (2901.000000?, 28.13?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2904.000000?, 33.09?, 28.10?]
# controller input = (2904.000000?, 28.10?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2907.000000?, 33.03?, 28.07?]
# controller input = (2907.000000?, 28.07?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2910.000000?, 32.98?, 28.04?]
# controller input = (2910.000000?, 28.04?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2913.000000?, 32.93?, 28.01?]
# controller input = (2913.000000?, 28.01?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2916.000000?, 32.88?, 27.98?]
# controller input = (2916.000000?, 27.98?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2919.000000?, 32.82?, 27.95?]
# controller input = (2919.000000?, 27.95?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2922.000000?, 32.77?, 27.92?]
# controller input = (2922.000000?, 27.92?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2925.000000?, 32.72?, 27.89?]
# controller input = (2925.000000?, 27.89?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2928.000000?, 32.67?, 27.86?]
# controller input = (2928.000000?, 27.86?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2931.000000?, 32.62?, 27.83?]
# controller input = (2931.000000?, 27.83?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2934.000000?, 32.57?, 27.80?]
# controller input = (2934.000000?, 27.80?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2937.000000?, 32.51?, 27.77?]
# controller input = (2937.000000?, 27.77?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2940.000000?, 32.46?, 27.74?]
# controller input = (2940.000000?, 27.74?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2943.000000?, 32.41?, 27.71?]
# controller input = (2943.000000?, 27.71?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2946.000000?, 32.36?, 27.68?]
# controller input = (2946.000000?, 27.68?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2949.000000?, 32.31?, 27.66?]
# controller input = (2949.000000?, 27.66?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2952.000000?, 32.26?, 27.63?]
# controller input = (2952.000000?, 27.63?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2955.000000?, 32.21?, 27.60?]
# controller input = (2955.000000?, 27.60?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2958.000000?, 32.16?, 27.57?]
# controller input = (2958.000000?, 27.57?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2961.000000?, 32.11?, 27.54?]
# controller input = (2961.000000?, 27.54?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2964.000000?, 32.07?, 27.51?]
# controller input = (2964.000000?, 27.51?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2967.000000?, 32.02?, 27.49?]
# controller input = (2967.000000?, 27.49?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2970.000000?, 31.97?, 27.46?]
# controller input = (2970.000000?, 27.46?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2973.000000?, 31.92?, 27.43?]
# controller input = (2973.000000?, 27.43?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2976.000000?, 31.87?, 27.40?]
# controller input = (2976.000000?, 27.40?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2979.000000?, 31.82?, 27.37?]
# controller input = (2979.000000?, 27.37?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2982.000000?, 31.78?, 27.35?]
# controller input = (2982.000000?, 27.35?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2985.000000?, 31.73?, 27.32?]
# controller input = (2985.000000?, 27.32?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2988.000000?, 31.68?, 27.29?]
# controller input = (2988.000000?, 27.29?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2991.000000?, 31.63?, 27.26?]
# controller input = (2991.000000?, 27.26?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2994.000000?, 31.59?, 27.24?]
# controller input = (2994.000000?, 27.24?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2997.000000?, 31.54?, 27.21?]
# controller input = (2997.000000?, 27.21?)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...

# %%
rs.values
# Out:
# [{'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': 0,
#   'heater_on': False},
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cadbee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6cadbdc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3db80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3da60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d5e0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 55.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3d040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca3dca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9da940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9daa60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9dab80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9daca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9dadc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c9daee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af573a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af574c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af575e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af57ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af693a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af694c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af695e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af69ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7d940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7da60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7db80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7dca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7ddc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6af7dee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecd940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecda60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecdb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecdca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecddc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aecdee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc01325e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cadb4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cadb3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedd940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedda60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aeddb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aeddca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aedddc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6aeddee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7be940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7bea60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7beb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7beca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7bedc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c7beee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d5323a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d5324c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d5325e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6d532ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a0303a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a0304c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a0305e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a030ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb13a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb14c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb15e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6cbb1ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc01443a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc01444c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc01445e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbfc0144ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96f940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96fa60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96fb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96fca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96fdc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c96fee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca743a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca744c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca745e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca74ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 604.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca093a0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 637.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7fbd6ca094c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca095e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6ca09ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93d940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93da60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93db80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93dca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93ddc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c93dee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90a940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90aa60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90ab80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90aca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90adc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbd6c90aee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a63a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a64c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a65e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997a6ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997833a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997834c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf997835e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99783ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf999773a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf999774c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf999775e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99977ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99940040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99940160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99940280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf999403a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf999404c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf999405e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99940700>,
# ...
#  <flowstar.reachability.Reach object at 0x7fbf997595e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99759ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976b940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976ba60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976bb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976bca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976bdc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9976bee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdf940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdfa60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdfb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdfca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdfdc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf99fdfee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefc940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefca60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefcb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefcca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefcdc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aefcee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2e940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2ea60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2eb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2eca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2edc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9af2eee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a1303a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a1304c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a1305e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130a60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130ca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a130ee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a3a0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a5e0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12a940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12aa60>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12ab80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12aca0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12adc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9a12aee0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aee8040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aee8160>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aee8280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7fbf9aee83a0>]

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 20000 graphics primitives

# %%
p = (  rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
     + Atomic(T_A < RIF(26)).signal(rs, symbolic_composition=True).plot(y_range=(20, 40)) )
p.set_aspect_ratio('automatic')
p
# Out:
# Graphics object consisting of 20002 graphics primitives

# %%
p = (  rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
     + G(RIF(0, 50), Atomic(T_A < RIF(26))).signal(rs, symbolic_composition=True).plot(y_range=(20, 40)) )
p.set_aspect_ratio('automatic')
p
# Out:
# In G.signal
# mask for G = None
# Graphics object consisting of 20002 graphics primitives

# %%
p = (  rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
     + F(RIF(0, 50), Atomic(T_A < RIF(26))).signal(rs, symbolic_composition=True).plot(y_range=(20, 40)) )
p.set_aspect_ratio('automatic')
p
# Out:
# mask for F = None
# Graphics object consisting of 20002 graphics primitives

# %% [markdown]
# With control based on a fixed input temperature of $20.0$

# %%
fspm = HybridSimulator(
    intervalfourpm,
    PeriodicBurstIncubatorController(
        {'current_state': IncubatorState.COOLING_DOWN, 'next_time': RIF(0), 'heater_on': False},
        heating_time=22, heating_gap=31, temperature_desired=35, lower_bound=10,
    ),
    controller_input_map=(lambda x: (x[0], RIF("20.0"))),
    controller_output_map=(lambda xin, x: xin),
)

# %%
rs = fspm.run(RIF(3000), RIF(3))
# Out:
# x = [0, 25, 3.?e1]
# controller input = (0, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [3.00000000000?, 25.0?, 3.?e1]
# controller input = (3.00000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [6.0000000000?, 26.5?, 3.?e1]
# controller input = (6.0000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [9.0000000000?, 28.0?, 3.?e1]
# controller input = (9.0000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [12.000000000?, 30.?, 3.?e1]
# controller input = (12.000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [15.000000000?, 31.?, 3.?e1]
# controller input = (15.000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [18.000000000?, 33.?, 3.?e1]
# controller input = (18.000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [21.000000000?, 34.?, 3.?e1]
# controller input = (21.000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 22, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [24.000000000?, 36.?, 3.?e1]
# controller input = (24.000000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 55.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [27.000000000?, 37.?, 3.?e1]
# controller input = (27.000000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [30.000000000?, 37.?, 3.?e1]
# controller input = (30.000000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [33.00000000?, 37.?, 3.?e1]
# controller input = (33.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [36.00000000?, 38.?, 3.?e1]
# controller input = (36.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [39.00000000?, 40.?, 3.?e1]
# controller input = (39.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [42.00000000?, 41.?, 26.?]
# controller input = (42.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [45.00000000?, 42.?, 3.?e1]
# controller input = (45.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [48.00000000?, 44.?, 27.?]
# controller input = (48.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [51.00000000?, 45.?, 3.?e1]
# controller input = (51.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 52.000000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [54.00000000?, 46.?, 28.?]
# controller input = (54.00000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 85.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [57.00000000?, 48.?, 3.?e1]
# controller input = (57.00000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [60.00000000?, 48.?, 29.?]
# controller input = (60.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [63.00000000?, 47.?, 29.?]
# controller input = (63.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [66.00000000?, 49.?, 30.?]
# controller input = (66.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [69.00000000?, 50.?, 30.?]
# controller input = (69.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [72.00000000?, 51.?, 31.?]
# controller input = (72.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [75.00000000?, 53.?, 31.?]
# controller input = (75.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [78.00000000?, 54.?, 32.?]
# controller input = (78.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [81.00000000?, 55.?, 32.?]
# controller input = (81.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 82.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [84.00000000?, 57.?, 33.?]
# controller input = (84.00000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 115.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [87.00000000?, 58.?, 33.?]
# controller input = (87.00000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [90.00000000?, 58.?, 34.?]
# controller input = (90.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [93.00000000?, 57.?, 34.?]
# controller input = (93.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [96.00000000?, 59.?, 35.?]
# controller input = (96.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [99.00000000?, 60.?, 35.?]
# controller input = (99.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [102.00000000?, 61.?, 36.?]
# controller input = (102.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [105.00000000?, 63.?, 36.?]
# controller input = (105.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [108.00000000?, 64.?, 37.?]
# controller input = (108.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [111.00000000?, 65.?, 37.?]
# controller input = (111.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 112.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [114.00000000?, 66.?, 38.?]
# controller input = (114.00000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 145.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [117.00000000?, 68.?, 39.?]
# controller input = (117.00000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [120.00000000?, 67.?, 39.?]
# controller input = (120.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [123.00000000?, 67.?, 40.?]
# controller input = (123.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [126.00000000?, 68.?, 40.?]
# controller input = (126.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [129.00000000?, 69.?, 41.?]
# controller input = (129.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [132.00000000?, 71.?, 41.?]
# controller input = (132.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [135.00000000?, 72.?, 42.?]
# controller input = (135.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [138.00000000?, 73.?, 42.?]
# controller input = (138.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [141.00000000?, 74.?, 43.?]
# controller input = (141.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 142.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [144.00000000?, 75.?, 43.?]
# controller input = (144.00000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 175.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [147.00000000?, 77.?, 44.?]
# controller input = (147.00000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [150.00000000?, 76.?, 44.?]
# controller input = (150.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [153.00000000?, 76.?, 45.?]
# controller input = (153.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [156.00000000?, 77.?, 45.?]
# controller input = (156.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [159.00000000?, 78.?, 46.?]
# controller input = (159.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [162.00000000?, 80.?, 46.?]
# controller input = (162.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [165.00000000?, 81.?, 47.?]
# controller input = (165.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [168.00000000?, 82.?, 47.?]
# controller input = (168.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [171.00000000?, 83.?, 48.?]
# controller input = (171.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 172.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [174.00000000?, 84.?, 48.?]
# controller input = (174.00000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 205.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [177.00000000?, 85.?, 49.?]
# controller input = (177.00000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [180.00000000?, 85.?, 49.?]
# controller input = (180.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [183.00000000?, 85.?, 50.?]
# controller input = (183.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [186.00000000?, 86.?, 50.?]
# controller input = (186.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [189.00000000?, 87.?, 51.?]
# controller input = (189.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [192.00000000?, 88.?, 51.?]
# controller input = (192.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [195.00000000?, 89.?, 52.?]
# controller input = (195.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [198.00000000?, 90.?, 52.?]
# controller input = (198.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [201.00000000?, 92.?, 53.?]
# controller input = (201.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 202.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [204.00000000?, 93.?, 53.?]
# controller input = (204.00000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 235.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [207.00000000?, 94.?, 54.?]
# controller input = (207.00000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [210.00000000?, 93.?, 54.?]
# controller input = (210.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [213.00000000?, 93.?, 54.?]
# controller input = (213.00000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [216.0000000?, 94.?, 55.?]
# controller input = (216.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [219.0000000?, 95.?, 55.?]
# controller input = (219.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [222.0000000?, 96.?, 56.?]
# controller input = (222.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [225.0000000?, 97.?, 56.?]
# controller input = (225.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [228.0000000?, 99.?, 57.?]
# controller input = (228.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [231.0000000?, 100.?, 57.?]
# controller input = (231.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 232.00000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [234.0000000?, 101.?, 58.?]
# controller input = (234.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 265.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [237.0000000?, 102.?, 58.?]
# controller input = (237.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [240.0000000?, 101.?, 59.?]
# controller input = (240.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [243.0000000?, 101.?, 59.?]
# controller input = (243.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [246.0000000?, 102.?, 59.?]
# controller input = (246.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [249.0000000?, 103.?, 60.?]
# controller input = (249.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [252.0000000?, 104.?, 60.?]
# controller input = (252.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [255.0000000?, 105.?, 61.?]
# controller input = (255.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [258.0000000?, 106.?, 61.?]
# controller input = (258.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [261.0000000?, 107.?, 62.?]
# controller input = (261.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 262.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [264.0000000?, 108.?, 62.?]
# controller input = (264.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 295.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [267.0000000?, 109.?, 63.?]
# controller input = (267.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [270.0000000?, 109.?, 63.?]
# controller input = (270.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [273.0000000?, 108.?, 63.?]
# controller input = (273.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [276.0000000?, 109.?, 64.?]
# controller input = (276.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [279.0000000?, 111.?, 64.?]
# controller input = (279.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [282.0000000?, 112.?, 65.?]
# controller input = (282.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [285.0000000?, 113.?, 65.?]
# controller input = (285.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [288.0000000?, 114.?, 65.?]
# controller input = (288.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [291.0000000?, 115.?, 66.?]
# controller input = (291.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 292.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [294.0000000?, 116.?, 66.?]
# controller input = (294.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 325.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [297.0000000?, 117.?, 67.?]
# controller input = (297.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [300.0000000?, 116.?, 67.?]
# controller input = (300.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [303.0000000?, 116.?, 68.?]
# controller input = (303.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [306.0000000?, 117.?, 68.?]
# controller input = (306.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [309.0000000?, 118.?, 68.?]
# controller input = (309.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [312.0000000?, 119.?, 69.?]
# controller input = (312.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [315.0000000?, 120.?, 69.?]
# controller input = (315.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [318.0000000?, 121.?, 70.?]
# controller input = (318.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [321.0000000?, 122.?, 70.?]
# controller input = (321.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 322.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [324.0000000?, 123.?, 70.?]
# controller input = (324.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 355.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [327.0000000?, 124.?, 71.?]
# controller input = (327.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [330.0000000?, 123.?, 71.?]
# controller input = (330.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [333.0000000?, 123.?, 72.?]
# controller input = (333.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [336.0000000?, 124.?, 72.?]
# controller input = (336.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [339.0000000?, 125.?, 72.?]
# controller input = (339.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [342.0000000?, 126.?, 73.?]
# controller input = (342.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [345.0000000?, 126.?, 73.?]
# controller input = (345.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [348.0000000?, 127.?, 73.?]
# controller input = (348.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [351.0000000?, 128.?, 74.?]
# controller input = (351.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 352.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [354.0000000?, 129.?, 74.?]
# controller input = (354.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 385.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [357.0000000?, 130.?, 75.?]
# controller input = (357.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [360.0000000?, 130.?, 75.?]
# controller input = (360.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [363.0000000?, 129.?, 75.?]
# controller input = (363.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [366.0000000?, 130.?, 76.?]
# controller input = (366.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [369.0000000?, 131.?, 76.?]
# controller input = (369.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [372.0000000?, 132.?, 76.?]
# controller input = (372.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [375.0000000?, 133.?, 77.?]
# controller input = (375.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [378.0000000?, 134.?, 77.?]
# controller input = (378.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [381.0000000?, 135.?, 78.?]
# controller input = (381.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 382.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [384.0000000?, 136.?, 78.?]
# controller input = (384.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 415.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [387.0000000?, 137.?, 78.?]
# controller input = (387.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [390.0000000?, 136.?, 79.?]
# controller input = (390.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [393.0000000?, 135.?, 79.?]
# controller input = (393.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [396.0000000?, 136.?, 79.?]
# controller input = (396.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [399.0000000?, 137.?, 80.?]
# controller input = (399.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [402.0000000?, 138.?, 80.?]
# controller input = (402.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [405.0000000?, 139.?, 80.?]
# controller input = (405.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [408.0000000?, 140.?, 81.?]
# controller input = (408.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [411.0000000?, 141.?, 80.7?]
# controller input = (411.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 412.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [414.0000000?, 142.?, 81.?]
# controller input = (414.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 445.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [417.0000000?, 143.?, 82.?]
# controller input = (417.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [420.0000000?, 142.?, 82.?]
# controller input = (420.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [423.0000000?, 141.?, 83.?]
# controller input = (423.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [426.0000000?, 142.?, 83.?]
# controller input = (426.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [429.0000000?, 143.?, 83.?]
# controller input = (429.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [432.0000000?, 144.?, 83.?]
# controller input = (432.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [435.0000000?, 145.?, 83.4?]
# controller input = (435.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [438.0000000?, 146.?, 84.?]
# controller input = (438.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [441.0000000?, 147.?, 84.1?]
# controller input = (441.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 442.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [444.0000000?, 148.?, 85.?]
# controller input = (444.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 475.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [447.0000000?, 149.?, 85.?]
# controller input = (447.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [450.0000000?, 148.?, 86.?]
# controller input = (450.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [453.0000000?, 147.?, 86.?]
# controller input = (453.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [456.0000000?, 148.?, 86.?]
# controller input = (456.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [459.0000000?, 149.?, 86.?]
# controller input = (459.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [462.0000000?, 150.?, 87.?]
# controller input = (462.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [465.0000000?, 151.?, 87.?]
# controller input = (465.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [468.0000000?, 152.?, 87.0?]
# controller input = (468.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [471.0000000?, 152.?, 88.?]
# controller input = (471.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 472.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [474.0000000?, 153.?, 87.7?]
# controller input = (474.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 505.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [477.0000000?, 154.?, 88.?]
# controller input = (477.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [480.0000000?, 153.?, 89.?]
# controller input = (480.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [483.0000000?, 153.?, 89.?]
# controller input = (483.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [486.0000000?, 154.?, 89.?]
# controller input = (486.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [489.0000000?, 154.?, 89.2?]
# controller input = (489.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [492.0000000?, 155.?, 89.5?]
# controller input = (492.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [495.0000000?, 156.?, 89.8?]
# controller input = (495.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [498.0000000?, 157.?, 91.?]
# controller input = (498.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [501.0000000?, 158.?, 91.?]
# controller input = (501.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 502.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [504.0000000?, 159.?, 91.?]
# controller input = (504.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 535.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [507.0000000?, 159.?, 92.?]
# controller input = (507.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [510.0000000?, 159.?, 92.?]
# controller input = (510.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [513.0000000?, 158.?, 91.7?]
# controller input = (513.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [516.0000000?, 159.?, 92.?]
# controller input = (516.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [519.0000000?, 160.?, 93.?]
# controller input = (519.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [522.0000000?, 161.?, 92.5?]
# controller input = (522.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [525.0000000?, 161.?, 92.8?]
# controller input = (525.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [528.0000000?, 162.?, 93.1?]
# controller input = (528.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [531.0000000?, 163.?, 93.4?]
# controller input = (531.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 532.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [534.0000000?, 164.?, 94.?]
# controller input = (534.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 565.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [537.0000000?, 165.?, 94.?]
# controller input = (537.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [540.0000000?, 164.?, 95.?]
# controller input = (540.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [543.0000000?, 163.?, 94.6?]
# controller input = (543.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [546.0000000?, 164.?, 95.?]
# controller input = (546.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [549.0000000?, 165.?, 95.1?]
# controller input = (549.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [552.0000000?, 165.?, 95.4?]
# controller input = (552.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [555.0000000?, 166.?, 96.?]
# controller input = (555.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [558.0000000?, 167.?, 96.?]
# controller input = (558.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [561.0000000?, 168.?, 97.?]
# controller input = (561.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 562.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [564.0000000?, 169.?, 97.?]
# controller input = (564.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 595.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [567.0000000?, 169.?, 97.?]
# controller input = (567.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [570.0000000?, 169.?, 98.?]
# controller input = (570.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [573.0000000?, 168.?, 97.4?]
# controller input = (573.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [576.0000000?, 169.?, 98.?]
# controller input = (576.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [579.0000000?, 169.?, 98.?]
# controller input = (579.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [582.0000000?, 170.?, 99.?]
# controller input = (582.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [585.0000000?, 171.?, 98.4?]
# controller input = (585.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [588.0000000?, 172.?, 99.?]
# controller input = (588.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [591.0000000?, 173.?, 99.?]
# controller input = (591.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 592.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [594.0000000?, 173.?, 100.?]
# controller input = (594.0000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 625.0000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [597.0000000?, 174.?, 100.?]
# controller input = (597.0000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [600.0000000?, 173.?, 100.?]
# controller input = (600.0000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 622.0000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [603.0000000?, 172.?, 100.?]
# controller input = (603.0000000?, 20)
# ...
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2812.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2805.000000?, 269.19?, 155.47?]
# controller input = (2805.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2812.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2808.000000?, 269.51?, 155.49?]
# controller input = (2808.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2812.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2811.000000?, 269.83?, 155.52?]
# controller input = (2811.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2812.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2814.000000?, 270.15?, 155.56?]
# controller input = (2814.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 2845.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2817.000000?, 270.47?, 155.61?]
# controller input = (2817.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2820.000000?, 269.24?, 155.63?]
# controller input = (2820.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2823.000000?, 268.03?, 155.61?]
# controller input = (2823.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2826.000000?, 268.36?, 155.58?]
# controller input = (2826.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2829.000000?, 268.70?, 155.56?]
# controller input = (2829.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2832.000000?, 269.03?, 155.56?]
# controller input = (2832.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2835.000000?, 269.35?, 155.56?]
# controller input = (2835.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2838.000000?, 269.67?, 155.58?]
# controller input = (2838.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2841.000000?, 269.99?, 155.61?]
# controller input = (2841.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2842.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2844.000000?, 270.31?, 155.65?]
# controller input = (2844.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 2875.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2847.000000?, 270.62?, 155.70?]
# controller input = (2847.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2850.000000?, 269.40?, 155.72?]
# controller input = (2850.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2853.000000?, 268.18?, 155.70?]
# controller input = (2853.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2856.000000?, 268.52?, 155.67?]
# controller input = (2856.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2859.000000?, 268.85?, 155.65?]
# controller input = (2859.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2862.000000?, 269.18?, 155.64?]
# controller input = (2862.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2865.000000?, 269.50?, 155.65?]
# controller input = (2865.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2868.000000?, 269.83?, 155.67?]
# controller input = (2868.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2871.000000?, 270.14?, 155.70?]
# controller input = (2871.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2872.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2874.000000?, 270.46?, 155.74?]
# controller input = (2874.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 2905.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2877.000000?, 270.77?, 155.78?]
# controller input = (2877.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2880.000000?, 269.54?, 155.81?]
# controller input = (2880.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2883.000000?, 268.33?, 155.79?]
# controller input = (2883.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2886.000000?, 268.67?, 155.76?]
# controller input = (2886.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2889.000000?, 269.00?, 155.74?]
# controller input = (2889.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2892.000000?, 269.33?, 155.73?]
# controller input = (2892.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2895.000000?, 269.65?, 155.73?]
# controller input = (2895.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2898.000000?, 269.97?, 155.75?]
# controller input = (2898.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2901.000000?, 270.29?, 155.78?]
# controller input = (2901.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2902.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2904.000000?, 270.60?, 155.82?]
# controller input = (2904.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 2935.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2907.000000?, 270.92?, 155.87?]
# controller input = (2907.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2910.000000?, 269.69?, 155.89?]
# controller input = (2910.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2913.000000?, 268.47?, 155.87?]
# controller input = (2913.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2916.000000?, 268.81?, 155.84?]
# controller input = (2916.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2919.000000?, 269.14?, 155.82?]
# controller input = (2919.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2922.000000?, 269.47?, 155.81?]
# controller input = (2922.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2925.000000?, 269.79?, 155.82?]
# controller input = (2925.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2928.000000?, 270.11?, 155.83?]
# controller input = (2928.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2931.000000?, 270.43?, 155.86?]
# controller input = (2931.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2932.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2934.000000?, 270.74?, 155.90?]
# controller input = (2934.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 2965.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2937.000000?, 271.05?, 155.95?]
# controller input = (2937.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2940.000000?, 269.82?, 155.97?]
# controller input = (2940.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2943.000000?, 268.61?, 155.95?]
# controller input = (2943.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2946.000000?, 268.94?, 155.92?]
# controller input = (2946.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2949.000000?, 269.27?, 155.89?]
# controller input = (2949.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2952.000000?, 269.60?, 155.89?]
# controller input = (2952.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2955.000000?, 269.92?, 155.89?]
# controller input = (2955.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2958.000000?, 270.24?, 155.91?]
# controller input = (2958.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2961.000000?, 270.56?, 155.94?]
# controller input = (2961.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2962.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2964.000000?, 270.87?, 155.97?]
# controller input = (2964.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 2995.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2967.000000?, 271.18?, 156.02?]
# controller input = (2967.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2970.000000?, 269.95?, 156.05?]
# controller input = (2970.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2973.000000?, 268.74?, 156.03?]
# controller input = (2973.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2976.000000?, 269.07?, 155.99?]
# controller input = (2976.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2979.000000?, 269.40?, 155.97?]
# controller input = (2979.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2982.000000?, 269.73?, 155.96?]
# controller input = (2982.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2985.000000?, 270.05?, 155.97?]
# controller input = (2985.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2988.000000?, 270.37?, 155.98?]
# controller input = (2988.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2991.000000?, 270.69?, 156.01?]
# controller input = (2991.000000?, 20)
# state = {'current_state': <IncubatorState.HEATING: 'Heating'>, 'next_time': 2992.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2994.000000?, 271.00?, 156.05?]
# controller input = (2994.000000?, 20)
# state = {'current_state': <IncubatorState.WAITING: 'Waiting'>, 'next_time': 3025.000000?, 'heater_on': True}
# running for [3.0000000000000000 .. 3.0000000000000000] ...
# x = [2997.000000?, 271.31?, 156.09?]
# controller input = (2997.000000?, 20)
# state = {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>, 'next_time': None, 'heater_on': False}
# running for [3.0000000000000000 .. 3.0000000000000000] ...

# %%
rs.values
# Out:
# [{'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': 0,
#   'heater_on': False},
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068b8adc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068b8aee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0670633a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0670635e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 22,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0670634c0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 55.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067063820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067063940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067063ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 52.000000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a160>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 85.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff06704a3a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff06704a4c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704a940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704aa60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704ab80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 82.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704aca0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 115.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06704adc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff06704aee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0707a7040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a73a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a74c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a75e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 112.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7820>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 145.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0707a7a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0707a7b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707a7ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 142.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707933a0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 175.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707934c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0707935e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff070793700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 172.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070793ee0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 205.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff070794160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff070794280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707943a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707944c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0707945e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 202.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794a60>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 235.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff070794ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff070794dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff070794ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c3a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c4c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 232.00000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c700>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 265.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079c820>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff07079c5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff07079c940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079ca60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079cb80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079cca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079cdc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff07079cee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 262.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca160>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 295.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671ca3a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671ca4c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ca940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671caa60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671cab80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 292.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671caca0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 325.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671cadc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671caee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671e4040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e43a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e44c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e45e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 322.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4820>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 355.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671e4a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671e4b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671e4ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 352.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec3a0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 385.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec4c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671ec5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0671ec700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ec940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671eca60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ecb80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ecca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ecdc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 382.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0671ecee0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 415.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672ac160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672ac280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac3a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac4c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672ac940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 412.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672aca60>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 445.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672acb80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672acca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672acdc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672acee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672853a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672854c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 442.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672855e0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 475.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067285820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067285940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067285ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 472.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8160>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 505.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672a83a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672a84c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a85e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 502.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8ca0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 535.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a8dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672a8ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672a6040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a63a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a64c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a65e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 532.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6820>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 565.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672a6a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0672a6b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0672a6ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 562.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f43a0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 595.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f44c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681f45e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681f4700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 592.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681f4ee0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 625.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681d4160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681d4280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d43a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d44c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d45e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 622.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4a60>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 655.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681d4ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681d4dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d4ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d63a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d64c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 652.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d65e0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 685.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681d6820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0681d6940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0681d6ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 682.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353160>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 715.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0683533a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0683534c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683535e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 712.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353ca0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 745.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068353dc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068353ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068374040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683743a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683744c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683745e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 742.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374820>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 775.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068374a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068374b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068374ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 772.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683523a0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 805.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683524c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0683525e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068352700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 802.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068352ee0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 835.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068340160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068340280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683403a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683404c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0683405e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 832.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340a60>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 865.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068340ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff068340dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff068340ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f6040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f6160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f6280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f63a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f64c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 862.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f65e0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 895.0000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff0699f6700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0699f6820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 892.0000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff0699f6940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 892.0000000?,
#   'heater_on': True},
# ...
#  <flowstar.reachability.Reach object at 0x7ff069fa44c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2722.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa45e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2722.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa4700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2722.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa4820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2722.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa4940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2722.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa4a60>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2755.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa4b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069fa4ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069fa4dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fa4ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f893a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f894c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2752.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f895e0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2785.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069f89820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069f89940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069f89ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2782.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa160>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2815.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069faa3a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069faa4c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faa940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faaa60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faab80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2812.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faaca0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2845.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069faadc0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069faaee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069fbd040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd3a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd4c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd5e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2842.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd820>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2875.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbd940>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069fbda60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff069fbdb80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbdca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbddc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff069fbdee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2872.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e453a0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2905.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e454c0>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e455e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e45700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2902.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e45ee0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2935.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43040>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e43160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e43280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e433a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e434c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e435e0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43700>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2932.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43a60>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2965.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43b80>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e43ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e43dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e43ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71160>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71280>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e713a0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e714c0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2962.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e715e0>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 2995.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71700>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e71820>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff067e71940>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71a60>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71b80>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71ca0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71dc0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff067e71ee0>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06ac40040>,
#  {'current_state': <IncubatorState.HEATING: 'Heating'>,
#   'next_time': 2992.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06ac40160>,
#  {'current_state': <IncubatorState.WAITING: 'Waiting'>,
#   'next_time': 3025.000000?,
#   'heater_on': True},
#  <flowstar.reachability.Reach object at 0x7ff06ac40280>,
#  {'current_state': <IncubatorState.COOLING_DOWN: 'CoolingDown'>,
#   'next_time': None,
#   'heater_on': False},
#  <flowstar.reachability.Reach object at 0x7ff06ac403a0>]

# %%
rs.plot(('T_A', 'T_H'), color=('blue', 'green'))
# Out:
# Graphics object consisting of 20000 graphics primitives

# %% [markdown]
# One major issue we have to deal with is jump detection on hybrid transitions. Whilst numerical simulators and my existing code triggers control jumps at the earliest time they can possibly occur, to do things properly, we should consider all of the jumps which could possibly occur, introducing nondeterminism in to the dynamics of the discrete part of the hybrid controller (this is roughly how Flow*  does things). We need to consider to what extent it is necessary to model this complexity in order to model the dynamics of the systems we need to handle.
#
# This consideration will be of crucial importance when using this model as a digital twin, since the running system will not have this same nondeterminism, but rather, will follow one particular sequence of possible control jumps. One option is to use a nondeterminstic controller model for the possible behaviours and then
#
# Another consideration is the restriction of control jumps to discrete timepoints (e.g. multiples of 3 sec). This is a key divergence between our simulation approach and how most exact hybrid systems simulators work and models an important aspect of how the digital twin will work, however, is this actually a necessary part of our digital twin as a predictive model? For example, could we use standand non-deterministic hybrid model to overapproximate all possible control decision timings?

# %% [markdown]
# ### Better controller design model
#
# A major problem with the previous method of simulating the controller is that we compute a Flowpipe based on a different (interval) initial set for each stage of the simulation. This means that we we convert the (preconditioned) Taylor models representing the Flowpipe back to intervals for each time-step so the accuracy of the overall verified-integration will be much closer to a classical interval numerical method than to proper TM based methods where TMs are used to track uncertainties over long time windows. The need to handle very long sequences of reach objects and the constant switches between Python and C++ code will also destroy the performance of the overall simulation method.
#
# A better way to simulate the decisions of a particular controller is to calculate a signal for the time windows on which a given control decision can occur and then use this to restrict the time domain of the computed reach sequence to compute all of the possible jump points at which a state transition could occur. This will allow us to use TMs to track the dynamics covering multiple control windows as long as no transitions actually occur, and also suggests a way to handle jumps nondeterminstically. In doing this, we could either, either snap jumps to discrete control intervals or handle as occuring nondeterministically over contrinuous time intervals. Overall, this is not as sophisticated as Flow*'s built in hybrid system handling but should be sufficient for this case study.

# %% [markdown]
# How tightly coupled should we be to the underlying dynamics?

# %% [markdown]
# ## Attempt at coupled plant modelling

# %%
from verified_twin.simulators import NumericalContinuousSimulator
from verified_twin.parametric_models import NumericalParametricModel

# %%
numericalsevenpincubator = NumericalParametricModel(
    "T_H,T_A,T_F",
    [QQ(20.0), QQ(20.0), QQ(20.0)],
    [
        (1/C_H)*(V*I - G_H*(T_H - T_A)),
        (1/C_A)*(G_H*(T_H - T_A) - G_B*(T_A - T_R) - G_F*(T_A - T_F)),
        (1/C_F)*G_F*(T_F - T_A),
    ],
    {
        "C_H": QQ(700.0),
        "C_A": QQ(700.0),
        "C_F": QQ(700.0),
        "V":   QQ(0.03),
        "I":   QQ(1.0),
        "T_R": QQ(18.0),
        "G_H": QQ(1.0),
        "G_B": QQ(1.0),
        "G_F": QQ(1.0),
    },
)

# %%
rs = NumericalContinuousSimulator({}, numericalsevenpincubator).run(time_limit=QQ(2000))
# Out:
# run_duration = 2000
# odes = (-1/700*T_H + 1/700*T_A + 3/70000, 1/700*T_H - 3/700*T_A + 1/700*T_F + 9/350, -1/700*T_A + 1/700*T_F)
# running for 2000 ...
# x = (20, 20, 20)

# %%
rs.values[0]
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 33
#      njev: 0
#       nlu: 0
#       sol: <scipy.integrate._ivp.common.OdeSolution object at 0x7ff06aab8a90>
#    status: 0
#   success: True
#         t: array([   0.        ,   60.81234345,  121.6246869 ,  255.56922333,
#         389.51375975,  523.45829617,  646.39017981,  769.32206345,
#         892.25394708,  981.63539405, 1071.01684102, 1160.39828798,
#        1271.57486224, 1382.7514365 , 1493.92801077, 1934.74685896,
#        2000.        ])
#  t_events: None
#         y: array([[20, 19.992570021871693, 19.976751762721424, 19.926995273026762,
#         19.859355495014327, 19.79234417026471, 19.73899849053494,
#         19.69595825665736, 19.664486940503846, 19.649595901569555,
#         19.641940810675866, 19.641835549604828, 19.652760611595944,
#         19.6765584640304, 19.71397106555425, 20.014893106975936,
#         20.08277650684741],
#        [20, 19.85987959957853, 19.74963222966928, 19.566985859797832,
#         19.477813103673647, 19.440569669622796, 19.435294418678644,
#         19.452674467568816, 19.49089638350366, 19.53092655175904,
#         19.580985107508294, 19.641269702690167, 19.731060109940614,
#         19.8381184552324, 19.963669169203502, 20.67671619225367,
#         20.81656244695697],
#        [20, 20.01245212907526, 20.036683356700987, 20.116324809636033,
#         20.243399781807145, 20.410825610086476, 20.598725751555047,
#         20.82118714995222, 21.081040581251546, 21.295227629119747,
#         21.53246318752602, 21.794526044811235, 22.15826779665525,
#         22.56777938637611, 23.027871887699014, 25.464995521311334,
#         25.925852319168158]], dtype=object)
#  y_events: None

# %%
rs.plot((0, 1, 2), color=('red', 'green', 'orange'))
# Out:
# Graphics object consisting of 3 graphics primitives
